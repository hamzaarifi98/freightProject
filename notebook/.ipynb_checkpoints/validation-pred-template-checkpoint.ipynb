# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
df = pd.read_csv("validation-predictions-template.csv")

# %%
df.head()
# Out:
#      load_id  predicted_rate
# 0  TE-000001             NaN
# 1  TE-000002             NaN
# 2  TE-000003             NaN
# 3  TE-000004             NaN
# 4  TE-000005             NaN
